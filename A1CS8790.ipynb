% %%
DATA = load("-ascii", "DataA1.txt");

% %%
size(DATA)
% Out:
% ans =
%
%    100     1

% %%
DATA(1:10)
% Out:
% ans =
%
%    -49.021
%    173.064
%     26.709
%     37.440
%    -50.935
%    114.999
%    196.916
%     33.070
%     51.568
%    166.062

% %%
graphics_toolkit("gnuplot")
plot(1:100, DATA)

% %%
plot(1:100, arrayfun(@(n) mean(DATA(1:n)), 1:100))

% %%
mean(DATA)
% Out:
% ans =  0.0085598
